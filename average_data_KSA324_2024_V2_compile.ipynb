# %% [markdown]
# Process several CTD profiles, add nutrient data and merge to just one table.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# File names:

# %%
filenames = ['in2024_t01_001.cnv', 'in2024_t01_002.cnv', 'in2024_t01_003.cnv', 'in2024_t01_004.cnv', 
             'in2024_t01_005.cnv', 'in2024_t01_006.cnv', 'in2024_t01_007.cnv']

# %% [markdown]
# The loop below iterates throught the files, processes the data, and then stacks them vertically.

# %%
for i in range(len(filenames)):
    if i == 0:
        # Open file and assign column names
        column_names = ['t090C', 'c0Sm', 'prDM', 't190C', 'c1Sm', 'sbeox0MmL', 'sbeox1MmL', 
                        'sal00', 'sal11', 'scan', 'timeS', 'pumps', 'latitude', 'longitude', 
                        'flECO_AFL', 'turbWETbb0', 'altM', 'bpos', 'nbf', 'par', 'wetCDOM', 'CStarTr0', 'flag']
        data = pd.read_table(filenames[i], skiprows = 345, sep='\\s+', names = column_names)
        # Remove data with pressure less than 12
        data = data.loc[data['prDM'] > 12]
        # Find the maximum pressure and use it to retain only the downcast
        max_pressure_idx = np.argmax(data['prDM'])
        data = data[:max_pressure_idx]
        # Group the pressure column and average to sample down to integers
        data['PressureInterval'] = data['prDM'].apply(lambda x: int(x))
        data = data.groupby('PressureInterval').mean().reset_index()
        data = data.drop(columns = 'prDM')
        # Add CTD number
        data['CTD_No'] = i+1
    else:
        # Open file and assign column names
        column_names = ['t090C', 'c0Sm', 'prDM', 't190C', 'c1Sm', 'sbeox0MmL', 'sbeox1MmL', 
                        'sal00', 'sal11', 'scan', 'timeS', 'pumps', 'latitude', 'longitude', 
                        'flECO_AFL', 'turbWETbb0', 'altM', 'bpos', 'nbf', 'par', 'wetCDOM', 'CStarTr0', 'flag']
        ds = pd.read_table(filenames[i], skiprows = 345, sep='\\s+', names = column_names)
        # Remove ds with pressure less than 12
        ds = ds.loc[ds['prDM'] > 12]
        # Find the maximum pressure and use it to retain only the downcast
        max_pressure_idx = np.argmax(ds['prDM'])
        ds = ds[:max_pressure_idx]
        # Group the pressure column and average to sample down to integers
        ds['PressureInterval'] = ds['prDM'].apply(lambda x: int(x))
        ds = ds.groupby('PressureInterval').mean().reset_index()
        ds = ds.drop(columns = 'prDM')
        ds['CTD_No'] = i+1
        data = pd.concat([data, ds], axis = 0)

# %% [markdown]
# Now we will import the nutrient data and use the rounded pressure column and CTD number to add nutrient info to our merged table.

# %%
nuts = pd.read_csv('Nuts_sorted_with_depth_v2.csv')
nuts
# Out:
#      Dep_No_  Bottle  pressureDb  NH4_uM NH4_flag  NOx_uM NOx_flag  \
# 0          1       4         147    0.03     Good    1.06     Good
# 1          1      11         110    0.02     Good    1.23     Good
# 2          1      18          87    0.06     Good    0.19     Good
# 3          1      22          40    0.03     Good    0.02     Good
# 4          1      23          20    0.02     Good    0.02     Good
# ..       ...     ...         ...     ...      ...     ...      ...
# 109        7      26          51     NaN      NaN     NaN      NaN
# 110        7      30          24    0.14     Good    0.14     Good
# 111        7      31          23     NaN      NaN     NaN      NaN
# 112        7      32          10    0.15     Good    0.13     Good
# 113        7      33          10     NaN      NaN     NaN      NaN
#
#      Nitrite_uM Nitrite_flag  PO4_uM PO4_flag  Silicate_uM Silicate_flag
# 0         0.072         Good    0.18     Good          1.7          Good
# 1         0.055         Good    0.19     Good          2.1          Good
# 2         0.083         Good    0.11     Good          1.6          Good
# 3         0.018         Good    0.07     Good          1.2          Good
# 4         0.016         Good    0.06     Good          1.1          Good
# ..          ...          ...     ...      ...          ...           ...
# 109         NaN          NaN     NaN      NaN          NaN           NaN
# 110       0.042         Good    0.19     Good         -0.2          Good
# 111         NaN          NaN     NaN      NaN          NaN           NaN
# 112       0.038         Good    0.19     Good         -0.2          Good
# 113         NaN          NaN     NaN      NaN          NaN           NaN
#
# [114 rows x 13 columns]

# %% [markdown]
# The nutrients data has `Dep_No` instead of `CTD_No`. Let's replace that. Same for the pressures

# %%
nuts = nuts.rename(columns = {'Dep_No_':'CTD_No', 'pressureDb':'PressureInterval'})
merged_table = pd.merge(data, nuts, on = ['CTD_No', 'PressureInterval'], how = 'outer')

# %% [markdown]
# Add chlorophyll data:

# %%
chlaData = pd.read_csv('In2024_T01_Chla_CTD.csv');
chlaData = chlaData.rename(columns = {'Bottle_No':'Bottle'})

# %%
merged_table = pd.merge(merged_table, chlaData, on = ['CTD_No', 'Bottle'], how = 'outer')

# %% [markdown]
# Finally, we want to replace the flags by numeric values. If it's good, we will replace with 0, and Suspect with 4.

# %%
for column in ['NH4_flag', 'NOx_flag', 'Nitrite_flag', 'PO4_flag', 'Silicate_flag']:
    idx = np.where(merged_table[column] == 'Good')[0]
    merged_table.loc[idx, column] = 0
    idx = np.where(merged_table[column] == 'Suspect')[0]
    merged_table.loc[idx, column] = 4

# %%
# Sort the table
merged_table.sort_values(['CTD_No', 'PressureInterval'], ascending = [True, True])
# Out:
#        PressureInterval      t090C      c0Sm      t190C      c1Sm   sbeox0MmL  \
# 5                    10        NaN       NaN        NaN       NaN         NaN
# 6                    12  21.515705  5.046881  21.520187  5.047049  211.406175
# 7                    13  21.519047  5.047248  21.521344  5.047171  211.692313
# 8                    14  21.516238  5.047015  21.513850  5.046500  212.040154
# 9                    15  21.483911  5.043525  21.492678  5.044185  211.552435
# ...                 ...        ...       ...        ...       ...         ...
# 20526              2208   2.127784  3.162202   2.128597  3.162278  165.136226
# 20527              2209   2.128281  3.162285   2.129088  3.162361  165.114539
# 20528              2210   2.128632  3.162356   2.129409  3.162429  165.163920
# 20529              2211   2.128968  3.162428   2.129706  3.162499  165.163860
# 20530              2212   2.128957  3.162442   2.129667  3.162513  165.152555
#
#         sbeox1MmL      sal00      sal11          scan  ...  NOx_uM  NOx_flag  \
# 5             NaN        NaN        NaN           NaN  ...    0.02         0
# 6      214.326250  35.794820  35.792435  15812.475000  ...     NaN       NaN
# 7      214.494656  35.794625  35.792084  15848.531250  ...     NaN       NaN
# 8      213.910598  35.794679  35.792569  15922.991453  ...     NaN       NaN
# 9      214.499804  35.793507  35.791467  16004.521739  ...     NaN       NaN
# ...           ...        ...        ...           ...  ...     ...       ...
# 20526  170.195857  34.730946  34.731017  78459.070199  ...     NaN       NaN
# 20527  170.205013  34.730937  34.731014  79299.613924  ...     NaN       NaN
# 20528  170.159095  34.730947  34.731006  80438.093775  ...     NaN       NaN
# 20529  170.217643  34.730946  34.731000  82236.554969  ...     NaN       NaN
# 20530  170.296663  34.730894  34.730974  83182.158654  ...     NaN       NaN
#
#        Nitrite_uM  Nitrite_flag  PO4_uM  PO4_flag  Silicate_uM  Silicate_flag  \
# 5           0.016             0    0.07         0          1.2              0
# 6             NaN           NaN     NaN       NaN          NaN            NaN
# 7             NaN           NaN     NaN       NaN          NaN            NaN
# 8             NaN           NaN     NaN       NaN          NaN            NaN
# 9             NaN           NaN     NaN       NaN          NaN            NaN
# ...           ...           ...     ...       ...          ...            ...
# 20526         NaN           NaN     NaN       NaN          NaN            NaN
# 20527         NaN           NaN     NaN       NaN          NaN            NaN
# 20528         NaN           NaN     NaN       NaN          NaN            NaN
# 20529         NaN           NaN     NaN       NaN          NaN            NaN
# 20530         NaN           NaN     NaN       NaN          NaN            NaN
#
#        Chla   Flag_ODV
# 5      0.116       0.0
# 6        NaN       NaN
# 7        NaN       NaN
# 8        NaN       NaN
# 9        NaN       NaN
# ...      ...       ...
# 20526    NaN       NaN
# 20527    NaN       NaN
# 20528    NaN       NaN
# 20529    NaN       NaN
# 20530    NaN       NaN
#
# [20531 rows x 37 columns]

# %%
merged_table.to_csv('merged_data_file.csv')
